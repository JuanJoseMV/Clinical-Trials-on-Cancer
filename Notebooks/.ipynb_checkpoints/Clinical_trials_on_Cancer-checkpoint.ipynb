# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import os

# %%
data = pd.read_csv('./Dataset/labeledEligibilitySample1000000.csv', header = None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-120735e57e07> in <module>
# ----> 1 data = pd.read_csv('./Dataset/labeledEligibilitySample1000000.csv', header = None)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./Dataset/labeledEligibilitySample1000000.csv' does not exist: b'./Dataset/labeledEligibilitySample1000000.csv'

# %%
data.shape
data.sample(20)
# Out:
#                  0                                                  1
# 669275  __label__1  study interventions are Mycophenolic Acid . st...
# 233236  __label__0  study interventions are Dacarbazine . breast c...
# 34147   __label__0  study interventions are Busulfan . lymphoma di...
# 470618  __label__0  study interventions are Antibodies, Monoclonal...
# 263492  __label__0  study interventions are Interferon-alpha . mul...
# 603721  __label__1  study interventions are Pemetrexed . breast ca...
# 656261  __label__1  study interventions are Cabozantinib S-malate ...
# 69218   __label__0  study interventions are Immunoglobulins . ovar...
# 661427  __label__1  study interventions are Fludarabine phosphate ...
# 472196  __label__0  study interventions are Prednisolone phosphate...
# 56393   __label__0  study interventions are Antibodies, Monoclonal...
# 73270   __label__0  study interventions are Fosaprepitant . breast...
# 990096  __label__1  study interventions are Niraparib . carcinoma ...
# 393627  __label__0  study interventions are Sirolimus . pancreatic...
# 259245  __label__0  study interventions are Dexamethasone acetate ...
# 226236  __label__0  study interventions are Fludarabine . kidney c...
# 272473  __label__0  study interventions are Pancrelipase . pancrea...
# 877638  __label__1  study interventions are ABBV-075 . advanced ca...
# 419227  __label__0  study interventions are Zoledronic acid . pros...
# 951903  __label__1  study interventions are Gemcitabine . non smal...

# %%
clin_trial = pd.DataFrame(np.array(data).reshape(1000000,2), columns=['Label', 'Description'])
clin_trial[:].head(10)
# Out:
#         Label                                        Description
# 0  __label__0  study interventions are recombinant CD40-ligan...
# 1  __label__0  study interventions are Liposomal doxorubicin ...
# 2  __label__0  study interventions are BI 836909 . multiple m...
# 3  __label__0  study interventions are Immunoglobulins . recu...
# 4  __label__0  study interventions are Paclitaxel . stage ova...
# 5  __label__0  study interventions are Antibodies, Monoclonal...
# 6  __label__0  study interventions are Hormones . prostate ca...
# 7  __label__0  study interventions are Bendamustine Hydrochlo...
# 8  __label__0  study interventions are Nivolumab . recovered ...
# 9  __label__0  study interventions are Thalidomide . kidney c...

# %%
clin_trial['Interventions'], clin_trial['Diagnoses'] = clin_trial['Description'].str.split('.', 1).str
clin_trial['Eligible'] = clin_trial['Label'].str.extract('(\d)', expand=True)

clin_trial=clin_trial.drop(['Description'], axis=1)
clin_trial=clin_trial.drop(['Label'], axis=1)

clin_trial.head(10)
# Out:
#                                        Interventions  \
# 0   study interventions are recombinant CD40-ligand
# 1     study interventions are Liposomal doxorubicin
# 2                 study interventions are BI 836909
# 3           study interventions are Immunoglobulins
# 4                study interventions are Paclitaxel
# 5    study interventions are Antibodies, Monoclonal
# 6                  study interventions are Hormones
# 7  study interventions are Bendamustine Hydrochlo...
# 8                 study interventions are Nivolumab
# 9               study interventions are Thalidomide
#
#                                            Diagnoses Eligible
# 0   melanoma skin diagnosis and no active cns met...        0
# 1     colorectal cancer diagnosis and cardiovascular        0
# 2   multiple myeloma diagnosis and indwelling cen...        0
# 3   recurrent fallopian tube carcinoma diagnosis ...        0
# 4   stage ovarian cancer diagnosis and patients m...        0
# 5   recurrent verrucous carcinoma of the oral cav...        0
# 6   prostate cancer diagnosis and imaging examina...        0
# 7   diffuse large cell lymphoma diagnosis and no ...        0
# 8   recovered from all toxicities associated with...        0
# 9   kidney cancer diagnosis and no diabetes mellitus        0

# %%
clin_trial['Interventions'] = clin_trial['Interventions'].str.replace("study interventions are\s", "")
clin_trial.sample(10)
# Out:
#                                    Interventions  \
# 203659                               Vidarabine
# 604150                                Sorafenib
# 966342  Ledipasvir, sofosbuvir drug combination
# 386433                             Lenalidomide
# 674312                              Floxuridine
# 139559                                Lapatinib
# 992716                               Nintedanib
# 331869                           Levoleucovorin
# 321972                          Immunoglobulins
# 546457                   Isophosphamide mustard
#
#                                                 Diagnoses Eligible
# 203659   fallopian tube cancer diagnosis and if biolog...        0
# 604150   breast cancer diagnosis and hypertension that...        1
# 966342   central nervous system cns disease meningeal ...        1
# 386433   extranodal marginal zone cell lymphoma of muc...        0
# 674312   stage iv ovarian cancer diagnosis and any of ...        1
# 139559   breast cancer diagnosis and hertwo neu positi...        0
# 992716   carcinoma non small cell lung diagnosis and t...        1
# 331869   stomach neoplasms diagnosis and no prior expo...        0
# 321972   recurrent mantle cell lymphoma diagnosis and ...        0
# 546457   adult supratentorial primitive neuroectoderma...        1

# %%
words['con'] = clin_trial.apply(lambda row: len(row['Diagnoses']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6e23714a9eaa> in <module>
# ----> 1 words['con'] = clin_trial.apply(lambda row: len(row['Diagnoses']), axis=1)
#
# NameError: name 'words' is not defined

# %%
words
